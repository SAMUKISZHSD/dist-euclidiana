# %%
import pandas as pd

# %%
df = pd.read_csv('base_agencias_expandida_corrigida.csv', sep=';')
df.to_csv('../base_agencias_ficticia.csv', index=False)
df
# Out:
#        agencia     ti      to  indice_indisp  vol_atms  vol_transacao  \
# 0            0   7280  120986       0.060172        19           7932
# 1            0   1979   79028       0.025042        18          19386
# 2            0   7280  120986       0.060172        19           7932
# 3            0   1979   79028       0.025042        18          19386
# 4            0   7280  120986       0.060172        19           7932
# ...        ...    ...     ...            ...       ...            ...
# 34995     9998  10560   71618       0.147449        16          14169
# 34996     9998  10560   71618       0.147449        16          14169
# 34997     9998  10560   71618       0.147449        16          14169
# 34998     9998  10560   71618       0.147449        16          14169
# 34999     9998  10560   71618       0.147449        16          14169
#
#       grupo_controle onda_fechamento  anomes anomes_fechamento  \
# ...
